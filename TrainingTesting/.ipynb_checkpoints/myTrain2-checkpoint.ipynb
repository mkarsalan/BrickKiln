# %%
from __future__ import division
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import cv2
from random import shuffle
import random
import glob
from skimage.transform import resize
#from PIL import Image
import os
from model import *
# from keras.models import Model
# from keras.layers import Input, Dense
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Activation
# from keras.optimizers import SGD
# from keras.utils import np_utils
# from keras.layers import Input, Dense, Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D, Flatten, Activation, add
# from keras.optimizers import SGD
# from keras.layers.normalization import BatchNormalization
# from keras.models import Model
# from keras import initializers
# from keras.engine import Layer, InputSpec
# from keras import backend as K
# import keras
# from resnet152 import ResNet152
from keras.preprocessing import image
# from keras.applications.imagenet_utils import preprocess_input, decode_prediction
from keras.utils import to_categorical
import numpy as np


from collections import defaultdict
import itertools
from tqdm import tqdm
import time
import shutil
# Out:
# Using TensorFlow backend.

# %%
num_classes = 10

# %%
def load_dataset(dataset_path):
    folders = os.listdir(dataset_path)
    X = []
    y = []
    image_size = (256, 256)
    for i, folder in enumerate(folders):
        paths = glob.glob(os.path.join(dataset_path, folder+'/*[(.png)(.jpg)]'))
        label = np.ones(len(paths), dtype=np.int8) * i
        
        X += paths
        if (len(y)<1):
            y = label
        else:
            y = np.concatenate( (y, label), axis=0)
    
    images = np.array([cv2.imread(image_name) for image_name in X])    
    return images, to_categorical(y, num_classes)

def load_dataset_finetune(dataset_path):
    paths = glob.glob(os.path.join(dataset_path + '/*.png'))
    # 3 is for houses, 14 is for orchards
    label = np.ones(len(paths), dtype=np.int8) * 14
#     label = np.ones(len(paths), dtype=np.int8) * 3
    
    images = np.array([cv2.imread(image_name) for image_name in paths])    
    return images, to_categorical(label, num_classes)

def batch_generator(data_X, data_y, batch_size):
    indexes = np.array(range(len(data_y)))
    n = len(indexes)
    while True:
        batch_start = 0
        batch_end = batch_size
        np.random.shuffle(indexes)
        while batch_start < n:
            index = []
            batch_y = []
            y = []
            index = indexes[batch_start:batch_end]
            batch_x = np.array([data_X[i] for i in index])
            batch_y = np.array([data_y[i] for i in index])
            yield batch_x, batch_y
            batch_start += batch_size   
            batch_end += batch_size


def plot_confusion_matrix(cm, classes, ylabel, xlabel,
                          cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.colorbar()
    plt.grid()
    plt.title('Transitions from {} to {}'.format(ylabel, xlabel))
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)

# %%
# model_name = 'resNet152'
# dataset_path = '/media/waseem/3D0A87CA7D9EC477/M.Bhimra/mohbat_resnet/FINAL DATASET/dataset/houses'
model_name = 'resNet152_retrain_less'
#dataset_path = '/media/cvlab/5C08FA4008FA192A/M.Bhimra/transfer_data/FINAL DATASET/dataset/train'

# %%
X, y = load_dataset(dataset_path)
print ('Size of dataset:', len(y))
print(X.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# ('Size of dataset:', 6982)
# (6982, 256, 256, 3)

# %% [markdown]
# Display dataset stats

# %%
folders = os.listdir(dataset_path)
names, counts = [], []
for i, folder in enumerate(folders):
    dir_path = os.path.join(dataset_path, folder)
    images = os.listdir(dir_path)
    names.append(folder)
    counts.append(len(images))
    print(i, folder, len(images))
df = pd.DataFrame(data={'Name': names, 'Count': counts})
ax = df.plot(kind='bar', xticks=counts, grid=True, legend=False, figsize=(16,6))
ax.set_xlabel('Classes', fontsize=12)
ax.set_ylabel('Count', fontsize=12)
plt.xticks(np.arange(len(names)), names, rotation=45, fontsize=15)
for i, v in enumerate(counts):
    ax.text(i-.18, v+15, str(v), color='blue', fontweight='bold')
plt.show()
# Out:
# (0, 'blackfarms', 718)
# (1, 'densetrees', 700)
# (2, 'farms', 699)
# (3, 'grass', 699)
# (4, 'ground', 694)
# (5, 'houses', 703)
# (6, 'kiln', 694)
# (7, 'orchard', 693)
# (8, 'parking', 682)
# (9, 'roads', 715)

# %%
batch_size = 256
#train_gen = batch_generator(X_train, y_train, batch_size)
test_gen = batch_generator(X_test, y_test, batch_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5ca25418c4e2> in <module>()
#       1 batch_size = 256
#       2 #train_gen = batch_generator(X_train, y_train, batch_size)
# ----> 3 test_gen = batch_generator(X_test, y_test, batch_size)
#
# NameError: name 'X_test' is not defined

# %%
from resNet import *
input_shape=(256, 256, 3)
from keras.models import Sequential
# The '-1' is because we add a new class for finetuning
model = resNet(input_shape, num_classes, model_type='resnet_152')
model.load_weights(model_name+'.h5')
# model.load_weights('resNet152 (another copy).h5')

# # FINE TUNING HERE
# top_model = Sequential()
# top_model.add(Dense(input_shape=model.layers[-2].output_shape, units=num_classes, rnel
# kernel_initializer="he_normal", activation="softmax"))

# model.layers.pop()
# model.outputs = [model.layers[-1].output]
# model.layers[-1].outbound_nodes = []

# model = Model(inputs=model.inputs, outputs=top_model(model.outputs[0]))
# # for layer in model.layers[:-1]:
# #     layer.trainable = False

model.summary()
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print('accuracy')

#plot_model(model, to_file='model.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 128, 128, 64) 9472        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 128, 128, 64) 256         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 128, 128, 64) 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 64, 64, 64)   36928       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 64, 64, 64)   256         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 64, 64, 64)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 64, 64)   36928       activation_69[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 64, 64, 64)   0           max_pooling2d_2[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 64, 64, 64)   256         add_34[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 64, 64, 64)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 64, 64)   36928       activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 64, 64, 64)   256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 64, 64, 64)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 64, 64)   36928       activation_71[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 64, 64, 64)   0           add_34[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 64, 64, 64)   256         add_35[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 64, 64, 64)   0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 64, 64, 64)   36928       activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 64, 64, 64)   256         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 64, 64, 64)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 64, 64, 64)   36928       activation_73[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 64, 64, 64)   0           add_35[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 64, 64, 64)   256         add_36[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 64, 64, 64)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 32, 128)  73856       activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 32, 32, 128)  512         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 32, 32, 128)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 32, 32, 128)  8320        add_36[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 32, 32, 128)  147584      activation_75[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 32, 32, 128)  0           conv2d_80[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 32, 32, 128)  512         add_37[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 32, 32, 128)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 32, 32, 128)  147584      activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 32, 32, 128)  512         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 32, 32, 128)  0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 32, 32, 128)  147584      activation_77[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 32, 32, 128)  0           add_37[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 32, 32, 128)  512         add_38[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 32, 32, 128)  0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 32, 128)  147584      activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 32, 32, 128)  512         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 32, 32, 128)  0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 32, 128)  147584      activation_79[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 32, 32, 128)  0           add_38[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 32, 32, 128)  512         add_39[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 32, 32, 128)  0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 128)  147584      activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 32, 32, 128)  512         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 32, 32, 128)  0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 32, 32, 128)  147584      activation_81[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 32, 32, 128)  0           add_39[0][0]
#                                                                  conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 32, 32, 128)  512         add_40[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 32, 32, 128)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 256)  295168      activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 16, 16, 256)  1024        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 16, 16, 256)  0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 16, 16, 256)  33024       add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 256)  590080      activation_83[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 16, 16, 256)  0           conv2d_89[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 16, 16, 256)  1024        add_41[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 16, 16, 256)  0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 16, 16, 256)  590080      activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 16, 16, 256)  1024        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 16, 16, 256)  0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 16, 16, 256)  590080      activation_85[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 16, 16, 256)  0           add_41[0][0]
#                                                                  conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 16, 16, 256)  1024        add_42[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 16, 16, 256)  0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 16, 16, 256)  590080      activation_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 16, 16, 256)  1024        conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 16, 16, 256)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 16, 16, 256)  590080      activation_87[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 16, 16, 256)  0           add_42[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 16, 16, 256)  1024        add_43[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 16, 16, 256)  0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 16, 16, 256)  590080      activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 16, 16, 256)  1024        conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 16, 16, 256)  0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 16, 16, 256)  590080      activation_89[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 16, 16, 256)  0           add_43[0][0]
#                                                                  conv2d_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 16, 16, 256)  1024        add_44[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 16, 16, 256)  0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 16, 16, 256)  590080      activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 16, 16, 256)  1024        conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 16, 16, 256)  0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 16, 16, 256)  590080      activation_91[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 16, 16, 256)  0           add_44[0][0]
#                                                                  conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 16, 16, 256)  1024        add_45[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 16, 16, 256)  0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 16, 16, 256)  590080      activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 16, 16, 256)  1024        conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 16, 16, 256)  0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 16, 16, 256)  590080      activation_93[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 16, 16, 256)  0           add_45[0][0]
#                                                                  conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 16, 16, 256)  1024        add_46[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 16, 16, 256)  0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 16, 16, 256)  590080      activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 16, 16, 256)  1024        conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 16, 16, 256)  0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 16, 16, 256)  590080      activation_95[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 16, 16, 256)  0           add_46[0][0]
#                                                                  conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 16, 16, 256)  1024        add_47[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 16, 16, 256)  0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 16, 16, 256)  590080      activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 16, 16, 256)  1024        conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 16, 16, 256)  0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 16, 16, 256)  590080      activation_97[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 16, 16, 256)  0           add_47[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 16, 16, 256)  1024        add_48[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 16, 16, 256)  0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 16, 16, 256)  590080      activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 16, 16, 256)  1024        conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 16, 16, 256)  0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 16, 16, 256)  590080      activation_99[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 16, 16, 256)  0           add_48[0][0]
#                                                                  conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 16, 16, 256)  1024        add_49[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 16, 16, 256)  0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 16, 16, 256)  590080      activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 16, 16, 256)  1024        conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 16, 16, 256)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 16, 16, 256)  590080      activation_101[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 16, 16, 256)  0           add_49[0][0]
#                                                                  conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 16, 16, 256)  1024        add_50[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 16, 16, 256)  0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 16, 16, 256)  590080      activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 256)  1024        conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 16, 16, 256)  0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 16, 16, 256)  590080      activation_103[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 16, 16, 256)  0           add_50[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 256)  1024        add_51[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 16, 16, 256)  0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 16, 16, 256)  590080      activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 16, 16, 256)  1024        conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 16, 16, 256)  0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 16, 16, 256)  590080      activation_105[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 16, 16, 256)  0           add_51[0][0]
#                                                                  conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 16, 16, 256)  1024        add_52[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 16, 16, 256)  0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 16, 16, 256)  590080      activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 16, 16, 256)  1024        conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 16, 16, 256)  0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 16, 256)  590080      activation_107[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 16, 16, 256)  0           add_52[0][0]
#                                                                  conv2d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 16, 16, 256)  1024        add_53[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 16, 16, 256)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 16, 256)  590080      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 16, 16, 256)  1024        conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 16, 16, 256)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 16, 16, 256)  590080      activation_109[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 16, 16, 256)  0           add_53[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 16, 16, 256)  1024        add_54[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 16, 16, 256)  0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 16, 16, 256)  590080      activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 16, 16, 256)  1024        conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 16, 16, 256)  0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 16, 16, 256)  590080      activation_111[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 16, 16, 256)  0           add_54[0][0]
#                                                                  conv2d_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 16, 16, 256)  1024        add_55[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 16, 16, 256)  0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 16, 16, 256)  590080      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 16, 16, 256)  1024        conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 16, 16, 256)  0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 16, 16, 256)  590080      activation_113[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 16, 16, 256)  0           add_55[0][0]
#                                                                  conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 16, 16, 256)  1024        add_56[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 16, 16, 256)  0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 16, 16, 256)  590080      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 16, 16, 256)  1024        conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 16, 16, 256)  0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 16, 16, 256)  590080      activation_115[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 16, 16, 256)  0           add_56[0][0]
#                                                                  conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 16, 16, 256)  1024        add_57[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 16, 16, 256)  0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 16, 16, 256)  590080      activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 16, 16, 256)  1024        conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 16, 16, 256)  0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 16, 16, 256)  590080      activation_117[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 16, 16, 256)  0           add_57[0][0]
#                                                                  conv2d_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 16, 16, 256)  1024        add_58[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 16, 16, 256)  0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 16, 16, 256)  590080      activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 16, 16, 256)  1024        conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 16, 16, 256)  0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 16, 16, 256)  590080      activation_119[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 16, 16, 256)  0           add_58[0][0]
#                                                                  conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 16, 16, 256)  1024        add_59[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 16, 16, 256)  0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 16, 16, 256)  590080      activation_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 16, 16, 256)  1024        conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 16, 16, 256)  0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 16, 16, 256)  590080      activation_121[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 16, 16, 256)  0           add_59[0][0]
#                                                                  conv2d_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 16, 16, 256)  1024        add_60[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 16, 16, 256)  0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 16, 16, 256)  590080      activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 16, 16, 256)  1024        conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 16, 16, 256)  0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 16, 16, 256)  590080      activation_123[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 16, 16, 256)  0           add_60[0][0]
#                                                                  conv2d_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 16, 16, 256)  1024        add_61[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 16, 16, 256)  0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 16, 16, 256)  590080      activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 16, 16, 256)  1024        conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 16, 16, 256)  0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 16, 16, 256)  590080      activation_125[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 16, 16, 256)  0           add_61[0][0]
#                                                                  conv2d_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 16, 16, 256)  1024        add_62[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 16, 16, 256)  0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 16, 16, 256)  590080      activation_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 16, 16, 256)  1024        conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 16, 16, 256)  0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 16, 16, 256)  590080      activation_127[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 16, 16, 256)  0           add_62[0][0]
#                                                                  conv2d_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 16, 16, 256)  1024        add_63[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 16, 16, 256)  0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 8, 8, 512)    1180160     activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 8, 8, 512)    2048        conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 8, 8, 512)    0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 8, 8, 512)    131584      add_63[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 8, 8, 512)    2359808     activation_129[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 8, 8, 512)    0           conv2d_136[0][0]
#                                                                  conv2d_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 8, 8, 512)    2048        add_64[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 8, 8, 512)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 8, 8, 512)    2359808     activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 8, 8, 512)    2048        conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 8, 8, 512)    0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 8, 8, 512)    2359808     activation_131[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 8, 8, 512)    0           add_64[0][0]
#                                                                  conv2d_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 8, 8, 512)    2048        add_65[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 8, 8, 512)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 8, 512)    2359808     activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 8, 8, 512)    2048        conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 8, 8, 512)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 512)    2359808     activation_133[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 8, 8, 512)    0           add_65[0][0]
#                                                                  conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 8, 8, 512)    2048        add_66[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 8, 8, 512)    0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 512)    0           activation_134[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           5130        flatten_2[0][0]
# ==================================================================================================
# Total params: 41,409,290
# Trainable params: 41,376,650
# Non-trainable params: 32,640
# __________________________________________________________________________________________________
# accuracy

# %% [markdown]
# Train ResNet-152 network using "fit_generator"

# %%
checkpoint = ModelCheckpoint(model_name+'.h5', monitor='val_loss', verbose=2, save_best_only=True, mode='auto')
tensorboard = TensorBoard(log_dir='./', batch_size=batch_size, write_graph=True, write_images=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=3, min_lr=0.00001)
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=2, mode='auto')
cvslogger = keras.callbacks.CSVLogger(model_name+'.csv', separator=',', append=True)
 
nb_epoch = 200
callbacks = [checkpoint, reduce_lr, earlystop, cvslogger, tensorboard]
train_steps = int(len(y_train)//batch_size)
val_steps = int(len(y_test)//batch_size)
history = model.fit_generator(train_gen, train_steps, epochs=nb_epoch, verbose=1, 
                    max_queue_size=2, validation_data=test_gen, 
                    validation_steps=val_steps, shuffle=True,
                    workers=1, use_multiprocessing= False, 
                    initial_epoch=0, callbacks=callbacks)

#model.fit(x=X[0:100], y=y[0:100], batch_size=64, epochs=2, verbose=1, callbacks=callbacks, 
#          validation_split=0.2, shuffle=True,initial_epoch=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-573fc5c1e169> in <module>()
#       1 checkpoint = ModelCheckpoint(model_name+'.h5', monitor='val_loss', verbose=2, save_best_only=True, mode='auto')
# ----> 2 tensorboard = TensorBoard(log_dir='./', batch_size=batch_size, write_graph=True, write_images=True)
#       3 reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=3, min_lr=0.00001)
#       4 earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=2, mode='auto')
#       5 cvslogger = keras.callbacks.CSVLogger(model_name+'.csv', separator=',', append=True)
#
# NameError: name 'batch_size' is not defined

# %% [markdown]
# # sanity check

# %%
model.evaluate_generator(test_gen, steps=len(X_test)//batch_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d72bb03d4bb0> in <module>()
# ----> 1 model.evaluate_generator(test_gen, steps=len(X_test)//batch_size)
#
# NameError: name 'test_gen' is not defined

# %%
# test_images_dir = 'lhr/newtask'
test_images_dir = '/Users/arsalan/Desktop/SRP/places/zoomLevel_20'

# results_dir = 'results_lahore_17_with_old_wets_attempt2'
results_dir = '/Users/arsalan/Desktop/SRP/places/results/zoomLevel_20'
if not os.path.exists(results_dir):
    print('Creating new results directory "{}"'.format(results_dir))
    os.mkdir(results_dir)
im_dir = os.path.join(results_dir, 'images')
if not os.path.exists(im_dir):
    os.mkdir(im_dir)

#for file in os.listdir(test_images_dir):
#    curr_name, curr_ext = os.path.splitext(file)
 #   print(curr_name[:-1])
 #   break
#    new_name = curr_name[:-1]
#    os.rename(os.path.join(test_images_dir, file), os.path.join(test_images_dir, new_name+curr_ext))

########################################################
########### RENAMING DONE IN DOWNLOAD SCRIPT ###########
########################################################
# Out:
# Creating new results directory "/Users/arsalan/Desktop/SRP/places/results/zoomLevel_20"

# %% [markdown]
# Testing the model and creating result files

# %%
## print('Waiting'len(images)len(images)len(images), end='', flush=True)len(images)
# while True:
    
 #   if len(os.listdir(test_images_dir)) != 544244:
 #      time.sleep(10*60)
 #       print('.', end='', flush=True)
 #       continue


# if os.path.exists(os.path.join(results_dir, 'houses.txt')) or os.path.exists(os.path.join(results_dir, 'test.csv')):
#     raise OSError('Result files already present, this script will append to the existing data.')
    
# label_names = {0: 'parking', 1: 'parks', 2: 'ground', 3: 'houses', 4: 'roads', 5: 'mosque', 6: 'densetrees', 7: 'kiln', 8: 'oiltanks', 9: 'tennis', 10: 'ponds', 11: 'grass', 12: 'blackfarms', 13: 'farms', 14: 'orchard'}
# label_names = {0: 'parking', 1: 'parks', 2: 'ground', 3: 'houses', 4: 'roads', 5: 'mosque', 6: 'densetrees', 7: 'kiln', 8: 'oiltanks', 9: 'tennis', 10: 'ponds', 11: 'grass', 12: 'blackfarms', 13: 'farms'}
# label_names = {0: 'blackfarms', 1: 'densetrees', 2: 'farms', 3: 'grass', 4: 'ground', 5: 'houses', 6: 'kiln', 7: 'mosque', 8: 'oiltanks', 9: 'orchard', 10: 'parking', 11: 'parks', 12: 'ponds', 13: 'roads', 14: 'tennis'}
label_names = {0: 'blackfarms', 1: 'densetrees', 2: 'farms', 3: 'grass', 4: 'ground', 5: 'houses', 6: 'kiln', 7: 'orchard', 8: 'parking', 9: 'roads'}
y_tiles, x_tiles = [], []
label_probs = defaultdict(list)
top_label_probs = defaultdict(list)

# # Resuming check
# try:
#     with open(os.path.join(results_dir, 'last_file_done.txt'), 'r') as f:
#         loop_index = int(f.read())
#     print('Resuming from file index "{}"'.format(loop_index))
# except FileNotFoundError:
#     loop_index = 0
#     print('Starting fresh from file index "0"')

filenames = os.listdir(test_images_dir)

# # Missing images check
# try:
#     with open(os.path.join(results_dir, 'missing_images.txt'), 'r') as f:
#         missing_images = [name.strip() for name in f.readlines()]
#     print('Continuing with {} missing images.'.format(len(missing_images)))
# except FileNotFoundError:
#     missing_images = []
#     print('Starting fresh with empty missing images list')

for img_name in tqdm(filenames):
#     extt=img_name.split('.')[1]
    orig_name, extt = os.path.splitext(img_name)
    if(extt == '.jpg'):
        img_orig = cv2.imread(os.path.join(test_images_dir, img_name), cv2.IMREAD_COLOR)
        # To catch corrupt images
        if type(img_orig) == type(None):
            print('Skipping an image "{}"'.format(img_name))
        #    missing_images.append(img_name)
            continue
            
        img = np.expand_dims(img_orig, axis=0)
        class_name = img_name.split('.')[0]

        pred = model.predict(img, verbose=0)
    #    preds.append((pred.argmax(), pred.max(), class_name))
        
#         src = os.path.join(test_images_dir, img_name)
#         dst = os.path.join(results_dir, 'images', orig_name+'_'+label_names[pred.argmax()]+extt)
#         shutil.copyfile(src, dst)
#         print(img_name, dst)
        
#         break

#         lng,lat = os.path.splitext(img_name)[0].split('_')


#         lat, lng= os.path.splitext(img_name)[0].split('_')
        lat,lng = os.path.splitext(img_name)[0].split()
        y_tiles.append(lat)
        x_tiles.append(lng)

        # Append to individual results files on each itteration
        for i, label in label_names.items():
            file_path = os.path.join(results_dir, label+'.txt')
            label_probs[label].append(pred[0, i])
            with open(file_path, 'a') as f:
                f.write('{} {} {}\n'.format(lat, lng, pred[0, i]))
#         # Append to full result file on every 1000 itterations
#         #if loop_index % 1000 == 0:
#         d = {'y_tile': y_tiles, 'x_tile': x_tiles}
#         d.update(label_probs)
#         final_df = pd.DataFrame(data=d)
#         final_df.to_csv(os.path.join(results_dir, 'test.csv'), index=False, header=True)
        # Resuming 
        #with open('last_file_done.txt', 'w') as f:
         #   f.write(str(loop_index))
        # Write names of corrupted files for later use
        #with open(os.path.join(results_dir, 'missing.txt'), 'w') as f:
           # for i in missing_images:
           #     f.write('{}\n'.format(i))
        #loop_index += 1

        top3_inds = np.argsort(pred)
        top3_inds = np.flip(top3_inds, axis=1)
        top3_labels = [ label_names[i] for ia in top3_inds for i in ia ]
        top3_probs = pred[0, top3_inds]
#     print(top3_labels)

        for n in range(num_classes):
            top_label_probs['label'+str(n+1)].append(top3_labels[n])
            top_label_probs['prob'+str(n+1)].append(top3_probs[0, n])

# Append to full result file last time
d = {'lat': y_tiles, 'lng': x_tiles}
d.update(label_probs)
final_df = pd.DataFrame(data=d)
final_df.to_csv(os.path.join(results_dir, 'test.csv'), index=False, header=True)
# final_df

# Write names of corrupted files for later use
#with open(os.path.join(results_dir, 'missing.txt'), 'w') as f:
#    for i in missing_images:
#        f.write('{}\n'.format(i))

d = {'lat': y_tiles, 'lng': x_tiles}
d.update(top_label_probs)
sorted_df = pd.DataFrame(data=d)
sorted_df = sorted_df[['lat', 'lng', 'label1', 'prob1', 'label2', 'prob2', 'label3', 'prob3', 'label4', 'prob4', 'label5', 'prob5', 'label6', 'prob6', 'label7', 'prob7', 'label8', 'prob8', 'label9', 'prob9', 'label10', 'prob10']]
sorted_df.to_csv(os.path.join(results_dir, 'top_predictions.csv'), index=False, header=True)
# sorted_df.head()

# preds = sorted(preds, key=lambda x: x[0])
# for p_class, p_prob, truth in preds:
#     got_it = label_names[p_class] == truth
#     print('{}\tPrediction: {}\tTruth: {}\tProb: {}'.format(got_it, label_names[p_class], truth, p_prob))
#     break
# Out:
#   0%|          | 0/225 [00:00<?, ?it/s]
#
#   0%|          | 1/225 [00:00<01:48,  2.07it/s]
#
#   1%|          | 2/225 [00:00<01:50,  2.01it/s]
#
#   1%|▏         | 3/225 [00:01<01:55,  1.92it/s]
#
#   2%|▏         | 4/225 [00:02<01:59,  1.86it/s]
#
#   2%|▏         | 5/225 [00:02<01:55,  1.90it/s]
#
#   3%|▎         | 6/225 [00:03<01:57,  1.87it/s]
#
#   3%|▎         | 7/225 [00:04<02:06,  1.73it/s]
#
#   4%|▎         | 8/225 [00:04<02:10,  1.66it/s]
#
#   4%|▍         | 9/225 [00:05<02:13,  1.62it/s]
#
#   4%|▍         | 10/225 [00:06<02:12,  1.62it/s]
#
#   5%|▍         | 11/225 [00:06<02:11,  1.63it/s]
#
#   5%|▌         | 12/225 [00:07<02:09,  1.64it/s]
#
#   6%|▌         | 13/225 [00:07<02:08,  1.65it/s]
#
#   6%|▌         | 14/225 [00:08<02:10,  1.62it/s]
#
#   7%|▋         | 15/225 [00:09<02:12,  1.59it/s]
#
#   7%|▋         | 16/225 [00:10<02:12,  1.57it/s]
#
#   8%|▊         | 17/225 [00:10<02:11,  1.59it/s]
#
#   8%|▊         | 18/225 [00:11<02:11,  1.58it/s]
#
#   8%|▊         | 19/225 [00:11<02:09,  1.60it/s]
#
#   9%|▉         | 20/225 [00:12<02:06,  1.62it/s]
#
#   9%|▉         | 21/225 [00:12<02:04,  1.64it/s]
#
#  10%|▉         | 22/225 [00:13<02:02,  1.65it/s]
#
#  10%|█         | 23/225 [00:13<02:01,  1.67it/s]
#
#  11%|█         | 24/225 [00:14<02:00,  1.67it/s]
#
#  11%|█         | 25/225 [00:14<01:59,  1.67it/s]
#
#  12%|█▏        | 26/225 [00:15<01:58,  1.68it/s]
#
#  12%|█▏        | 27/225 [00:15<01:57,  1.69it/s]
#
#  12%|█▏        | 28/225 [00:16<01:55,  1.70it/s]
#
#  13%|█▎        | 29/225 [00:16<01:54,  1.71it/s]
#
#  13%|█▎        | 30/225 [00:17<01:53,  1.72it/s]
#
#  14%|█▍        | 31/225 [00:17<01:51,  1.74it/s]
#
#  14%|█▍        | 32/225 [00:18<01:50,  1.75it/s]
#
#  15%|█▍        | 33/225 [00:18<01:49,  1.75it/s]
#
#  15%|█▌        | 34/225 [00:19<01:49,  1.75it/s]
#
#  16%|█▌        | 35/225 [00:19<01:48,  1.76it/s]
#
#  16%|█▌        | 36/225 [00:20<01:47,  1.76it/s]
#
#  16%|█▋        | 37/225 [00:20<01:46,  1.77it/s]
#
#  17%|█▋        | 38/225 [00:21<01:45,  1.78it/s]
#
#  17%|█▋        | 39/225 [00:21<01:44,  1.79it/s]
#
#  18%|█▊        | 40/225 [00:22<01:43,  1.79it/s]
#
#  18%|█▊        | 41/225 [00:22<01:42,  1.80it/s]
#
#  19%|█▊        | 42/225 [00:23<01:41,  1.81it/s]
#
#  19%|█▉        | 43/225 [00:23<01:40,  1.81it/s]
#
#  20%|█▉        | 44/225 [00:24<01:39,  1.82it/s]
#
#  20%|██        | 45/225 [00:24<01:38,  1.82it/s]
#
#  20%|██        | 46/225 [00:25<01:38,  1.82it/s]
#
#  21%|██        | 47/225 [00:25<01:37,  1.82it/s]
#
#  21%|██▏       | 48/225 [00:26<01:37,  1.81it/s]
#
#  22%|██▏       | 49/225 [00:27<01:37,  1.81it/s]
#
#  22%|██▏       | 50/225 [00:27<01:36,  1.82it/s]
#
#  23%|██▎       | 51/225 [00:28<01:35,  1.82it/s]
#
#  23%|██▎       | 52/225 [00:28<01:35,  1.81it/s]
#
#  24%|██▎       | 53/225 [00:29<01:34,  1.81it/s]
#
#  24%|██▍       | 54/225 [00:29<01:34,  1.81it/s]
#
#  24%|██▍       | 55/225 [00:30<01:33,  1.82it/s]
#
#  25%|██▍       | 56/225 [00:31<01:33,  1.80it/s]
#
#  25%|██▌       | 57/225 [00:31<01:33,  1.79it/s]
#
#  26%|██▌       | 58/225 [00:32<01:33,  1.79it/s]
#
#  26%|██▌       | 59/225 [00:32<01:32,  1.79it/s]
#
#  27%|██▋       | 60/225 [00:33<01:32,  1.79it/s]
#
#  27%|██▋       | 61/225 [00:34<01:31,  1.79it/s]
#
#  28%|██▊       | 62/225 [00:34<01:31,  1.78it/s]
#
#  28%|██▊       | 63/225 [00:35<01:30,  1.79it/s]
#
#  28%|██▊       | 64/225 [00:35<01:30,  1.78it/s]
#
#  29%|██▉       | 65/225 [00:36<01:29,  1.78it/s]
#
#  29%|██▉       | 66/225 [00:37<01:29,  1.78it/s]
#
#  30%|██▉       | 67/225 [00:37<01:28,  1.79it/s]
#
#  30%|███       | 68/225 [00:38<01:27,  1.79it/s]
#
#  31%|███       | 69/225 [00:38<01:27,  1.79it/s]
#
#  31%|███       | 70/225 [00:38<01:26,  1.80it/s]
#
#  32%|███▏      | 71/225 [00:39<01:25,  1.80it/s]
#
#  32%|███▏      | 72/225 [00:39<01:24,  1.80it/s]
#
#  32%|███▏      | 73/225 [00:40<01:24,  1.80it/s]
#
#  33%|███▎      | 74/225 [00:41<01:24,  1.80it/s]
#
#  33%|███▎      | 75/225 [00:41<01:23,  1.80it/s]
#
#  34%|███▍      | 76/225 [00:42<01:22,  1.80it/s]
#
#  34%|███▍      | 77/225 [00:42<01:22,  1.80it/s]
#
#  35%|███▍      | 78/225 [00:43<01:21,  1.81it/s]
#
#  35%|███▌      | 79/225 [00:43<01:20,  1.81it/s]
#
#  36%|███▌      | 80/225 [00:44<01:20,  1.81it/s]
#
#  36%|███▌      | 81/225 [00:44<01:19,  1.81it/s]
#
#  36%|███▋      | 82/225 [00:45<01:18,  1.81it/s]
#
#  37%|███▋      | 83/225 [00:45<01:18,  1.81it/s]
#
#  37%|███▋      | 84/225 [00:46<01:18,  1.80it/s]
#
#  38%|███▊      | 85/225 [00:47<01:17,  1.80it/s]
#
#  38%|███▊      | 86/225 [00:47<01:17,  1.80it/s]
#
#  39%|███▊      | 87/225 [00:48<01:16,  1.80it/s]
#
#  39%|███▉      | 88/225 [00:48<01:16,  1.80it/s]
#
#  40%|███▉      | 89/225 [00:49<01:15,  1.80it/s]
#
#  40%|████      | 90/225 [00:49<01:14,  1.80it/s]
#
#  40%|████      | 91/225 [00:50<01:14,  1.80it/s]
#
#  41%|████      | 92/225 [00:51<01:13,  1.80it/s]
#
#  41%|████▏     | 93/225 [00:51<01:13,  1.81it/s]
#
#  42%|████▏     | 94/225 [00:52<01:12,  1.81it/s]
#
#  42%|████▏     | 95/225 [00:52<01:11,  1.81it/s]
#
#  43%|████▎     | 96/225 [00:53<01:11,  1.81it/s]
#
#  43%|████▎     | 97/225 [00:53<01:10,  1.81it/s]
#
#  44%|████▎     | 98/225 [00:54<01:10,  1.81it/s]
#
#  44%|████▍     | 99/225 [00:54<01:09,  1.81it/s]
#
#  44%|████▍     | 100/225 [00:55<01:09,  1.81it/s]
#
#  45%|████▍     | 101/225 [00:55<01:08,  1.81it/s]
#
#  45%|████▌     | 102/225 [00:56<01:08,  1.81it/s]
#
#  46%|████▌     | 103/225 [00:56<01:07,  1.81it/s]
#
#  46%|████▌     | 104/225 [00:57<01:06,  1.81it/s]
#
#  47%|████▋     | 105/225 [00:58<01:06,  1.81it/s]
#
#  47%|████▋     | 106/225 [00:58<01:05,  1.81it/s]
#
#  48%|████▊     | 107/225 [00:59<01:05,  1.81it/s]
#
#  48%|████▊     | 108/225 [00:59<01:04,  1.81it/s]
#
#  48%|████▊     | 109/225 [01:00<01:03,  1.81it/s]
#
#  49%|████▉     | 110/225 [01:00<01:03,  1.81it/s]
#
#  49%|████▉     | 111/225 [01:01<01:02,  1.81it/s]
#
#  50%|████▉     | 112/225 [01:01<01:02,  1.81it/s]
#
#  50%|█████     | 113/225 [01:02<01:01,  1.81it/s]
#
#  51%|█████     | 114/225 [01:02<01:01,  1.81it/s]
#
#  51%|█████     | 115/225 [01:03<01:00,  1.82it/s]
#
#  52%|█████▏    | 116/225 [01:03<01:00,  1.82it/s]
#
#  52%|█████▏    | 117/225 [01:04<00:59,  1.82it/s]
#
#  52%|█████▏    | 118/225 [01:04<00:58,  1.82it/s]
#
#  53%|█████▎    | 119/225 [01:05<00:58,  1.81it/s]
#
#  53%|█████▎    | 120/225 [01:06<00:57,  1.81it/s]
#
#  54%|█████▍    | 121/225 [01:06<00:57,  1.81it/s]
#
#  54%|█████▍    | 122/225 [01:07<00:56,  1.81it/s]
#
#  55%|█████▍    | 123/225 [01:07<00:56,  1.81it/s]
#
#  55%|█████▌    | 124/225 [01:08<00:55,  1.82it/s]
#
#  56%|█████▌    | 125/225 [01:08<00:55,  1.82it/s]
#
#  56%|█████▌    | 126/225 [01:09<00:54,  1.82it/s]
#
#  56%|█████▋    | 127/225 [01:09<00:53,  1.82it/s]
#
#  57%|█████▋    | 128/225 [01:10<00:53,  1.82it/s]
#
#  57%|█████▋    | 129/225 [01:10<00:52,  1.82it/s]
#
#  58%|█████▊    | 130/225 [01:11<00:52,  1.82it/s]
#
#  58%|█████▊    | 131/225 [01:11<00:51,  1.82it/s]
#
#  59%|█████▊    | 132/225 [01:12<00:51,  1.82it/s]
#
#  59%|█████▉    | 133/225 [01:13<00:50,  1.82it/s]
#
#  60%|█████▉    | 134/225 [01:13<00:50,  1.82it/s]
#
#  60%|██████    | 135/225 [01:14<00:49,  1.82it/s]
#
#  60%|██████    | 136/225 [01:14<00:48,  1.82it/s]
#
#  61%|██████    | 137/225 [01:15<00:48,  1.82it/s]
#
#  61%|██████▏   | 138/225 [01:15<00:47,  1.82it/s]
#
#  62%|██████▏   | 139/225 [01:16<00:47,  1.82it/s]
#
#  62%|██████▏   | 140/225 [01:17<00:46,  1.82it/s]
#
#  63%|██████▎   | 141/225 [01:17<00:46,  1.82it/s]
#
#  63%|██████▎   | 142/225 [01:18<00:45,  1.81it/s]
#
#  64%|██████▎   | 143/225 [01:18<00:45,  1.81it/s]
#
#  64%|██████▍   | 144/225 [01:19<00:44,  1.81it/s]
#  64%|██████▍   | 145/225 [01:19<00:44,  1.81it/s]
#
#  65%|██████▍   | 146/225 [01:20<00:43,  1.81it/s]
#
#  65%|██████▌   | 147/225 [01:21<00:43,  1.81it/s]
#
#  66%|██████▌   | 148/225 [01:21<00:42,  1.81it/s]
#
#  66%|██████▌   | 149/225 [01:22<00:42,  1.80it/s]
#
#  67%|██████▋   | 150/225 [01:23<00:41,  1.80it/s]
#
#  67%|██████▋   | 151/225 [01:23<00:40,  1.81it/s]
#
#  68%|██████▊   | 152/225 [01:24<00:40,  1.81it/s]
#
#  68%|██████▊   | 153/225 [01:24<00:39,  1.81it/s]
#
#  68%|██████▊   | 154/225 [01:25<00:39,  1.81it/s]
#
#  69%|██████▉   | 155/225 [01:25<00:38,  1.80it/s]
#
#  69%|██████▉   | 156/225 [01:26<00:38,  1.80it/s]
#
#  70%|██████▉   | 157/225 [01:27<00:37,  1.80it/s]
#
#  70%|███████   | 158/225 [01:27<00:37,  1.80it/s]
#
#  71%|███████   | 159/225 [01:28<00:36,  1.80it/s]
#
#  71%|███████   | 160/225 [01:28<00:36,  1.80it/s]
#
#  72%|███████▏  | 161/225 [01:29<00:35,  1.80it/s]
#
#  72%|███████▏  | 162/225 [01:30<00:35,  1.79it/s]
#
#  72%|███████▏  | 163/225 [01:30<00:34,  1.79it/s]
#
#  73%|███████▎  | 164/225 [01:31<00:34,  1.79it/s]
#
#  73%|███████▎  | 165/225 [01:32<00:33,  1.78it/s]
#
#  74%|███████▍  | 166/225 [01:33<00:33,  1.78it/s]
#
#  74%|███████▍  | 167/225 [01:33<00:32,  1.78it/s]
#
#  75%|███████▍  | 168/225 [01:34<00:32,  1.78it/s]
#
#  75%|███████▌  | 169/225 [01:35<00:31,  1.78it/s]
#
#  76%|███████▌  | 170/225 [01:35<00:30,  1.78it/s]
#
#  76%|███████▌  | 171/225 [01:36<00:30,  1.77it/s]
#
#  76%|███████▋  | 172/225 [01:36<00:29,  1.77it/s]
#
#  77%|███████▋  | 173/225 [01:37<00:29,  1.77it/s]
#
#  77%|███████▋  | 174/225 [01:38<00:28,  1.77it/s]
#
#  78%|███████▊  | 175/225 [01:38<00:28,  1.77it/s]
#
#  78%|███████▊  | 176/225 [01:39<00:27,  1.77it/s]
#
#  79%|███████▊  | 177/225 [01:39<00:27,  1.77it/s]
#
#  79%|███████▉  | 178/225 [01:40<00:26,  1.77it/s]
#
#  80%|███████▉  | 179/225 [01:41<00:26,  1.77it/s]
#
#  80%|████████  | 180/225 [01:42<00:25,  1.76it/s]
#
#  80%|████████  | 181/225 [01:42<00:24,  1.76it/s]
#
#  81%|████████  | 182/225 [01:43<00:24,  1.76it/s]
#
#  81%|████████▏ | 183/225 [01:44<00:23,  1.76it/s]
#
#  82%|████████▏ | 184/225 [01:44<00:23,  1.76it/s]
#
#  82%|████████▏ | 185/225 [01:45<00:22,  1.76it/s]
#
#  83%|████████▎ | 186/225 [01:45<00:22,  1.76it/s]
#
#  83%|████████▎ | 187/225 [01:46<00:21,  1.76it/s]
#
#  84%|████████▎ | 188/225 [01:46<00:20,  1.76it/s]
#
#  84%|████████▍ | 189/225 [01:47<00:20,  1.76it/s]
#
#  84%|████████▍ | 190/225 [01:47<00:19,  1.76it/s]
#
#  85%|████████▍ | 191/225 [01:48<00:19,  1.76it/s]
#
#  85%|████████▌ | 192/225 [01:48<00:18,  1.76it/s]
#
#  86%|████████▌ | 193/225 [01:49<00:18,  1.76it/s]
#
#  86%|████████▌ | 194/225 [01:50<00:17,  1.76it/s]
#
#  87%|████████▋ | 195/225 [01:50<00:17,  1.76it/s]
#
#  87%|████████▋ | 196/225 [01:51<00:16,  1.76it/s]
#
#  88%|████████▊ | 197/225 [01:51<00:15,  1.76it/s]
#
#  88%|████████▊ | 198/225 [01:52<00:15,  1.77it/s]
#
#  88%|████████▊ | 199/225 [01:52<00:14,  1.77it/s]
#
#  89%|████████▉ | 200/225 [01:53<00:14,  1.77it/s]
#
#  89%|████████▉ | 201/225 [01:53<00:13,  1.77it/s]
#
#  90%|████████▉ | 202/225 [01:54<00:13,  1.76it/s]
#
#  90%|█████████ | 203/225 [01:55<00:12,  1.77it/s]
#
#  91%|█████████ | 204/225 [01:55<00:11,  1.77it/s]
#
#  91%|█████████ | 205/225 [01:56<00:11,  1.77it/s]
#
#  92%|█████████▏| 206/225 [01:56<00:10,  1.77it/s]
#
#  92%|█████████▏| 207/225 [01:57<00:10,  1.77it/s]
#
#  92%|█████████▏| 208/225 [01:57<00:09,  1.77it/s]
#
#  93%|█████████▎| 209/225 [01:58<00:09,  1.77it/s]
#
#  93%|█████████▎| 210/225 [01:58<00:08,  1.77it/s]
#
#  94%|█████████▍| 211/225 [01:59<00:07,  1.77it/s]
#
#  94%|█████████▍| 212/225 [01:59<00:07,  1.77it/s]
#
#  95%|█████████▍| 213/225 [02:00<00:06,  1.77it/s]
#
#  95%|█████████▌| 214/225 [02:01<00:06,  1.77it/s]
#
#  96%|█████████▌| 215/225 [02:01<00:05,  1.77it/s]
#
#  96%|█████████▌| 216/225 [02:02<00:05,  1.77it/s]
#
#  96%|█████████▋| 217/225 [02:02<00:04,  1.77it/s]
#
#  97%|█████████▋| 218/225 [02:03<00:03,  1.77it/s]
#
#  97%|█████████▋| 219/225 [02:03<00:03,  1.77it/s]
#
#  98%|█████████▊| 220/225 [02:04<00:02,  1.77it/s]
#
#  98%|█████████▊| 221/225 [02:04<00:02,  1.77it/s]
#
#  99%|█████████▊| 222/225 [02:05<00:01,  1.77it/s]
#
#  99%|█████████▉| 223/225 [02:05<00:01,  1.77it/s]
#
# 100%|█████████▉| 224/225 [02:06<00:00,  1.77it/s]
#
# 100%|██████████| 225/225 [02:06<00:00,  1.77it/s]

# %% [markdown]
# import shutil
#
# for n in filenames[:200]:
#     src = os.path.join(test_images_dir, n)
#     dst = os.path.join('orchard_copy', n)
#     shutil.copyfile(src, dst)

# %%
def transition_probs(start, end, filename):
    imstart = cv2.imread(os.path.join(start, filename), cv2.IMREAD_COLOR)
    imend = cv2.imread(os.path.join(end, filename), cv2.IMREAD_COLOR)
    plt.imshow(cv2.cvtColor(imstart, cv2.COLHourOR_BGHourR2RGB))
    plt.imshow(cv2.cvtColor(imend, cv2.COLOR_BGR2RGB))
    
    if imstart is None or imend is None:
        raise OSError('Image "{}" not found in either "{}" or "{}"'.format(filename, start, end))
    
    imstart = np.expand_dims(imstart, axis=0)
    imend = np.expand_dims(imend, axis=0)

    predstart = model.predict(imstart, verbose=0)
    predend = model.predict(imend, verbose=0)

    return predstart.T * predend

# %% [markdown]
# Generate confusion matrices for each year

# %%
    
    
    
# dir11, dir13, dir17 = 'matilhr11', 'matilhr13', 'matilhr17'
dir11, dir13, dir17 = 'alpha', 'beta', 'gamma'

fig = plt.figure(figsize=(8,8))

filenames = os.listdir(dir11)
for filename in tqdm(filenames):
        from11to13 = transition_probs(dir11, dir13, filename)
        plot_confusion_matrix(from11to13, label_names.values(), '2011', '2013')
        plt.savefig(os.path.join('11_13', filename), bbox_inches='tight')

        plt.clf()
        from13to17 = transition_probs(dir13, dir17, filename)
        plot_confusion_matrix(from13to17, label_names.values(), '2013', '2017')
        plt.savefig(os.path.join('13_17', filename), bbox_inches='tight')

        plt.clf()
        from11to17 = transition_probs(dir11, dir17, filename)
        plot_confusion_matrix(from11to17, label_names.values(), '2011', '2017')
        plt.savefig(os.path.join('11_17', filename), bbox_inches='tight')
        plt.clf()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-26d8d6819554> in <module>()
#       7 fig = plt.figure(figsize=(8,8))
#       8
# ----> 9 filenames = os.listdir(dir11)
#      10 for filename in tqdm(filenames):
#      11     from11to13 = transition_probs(dir11, dir13, filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'alpha'

# %% [markdown]
# Merge confusion matrices by year

# %%
    
dir11, dir13, dir17 = '11_13', '13_17', '11_17'
out_dir = 'confusion_matrices'

fig = plt.figure(figsize=(8*3,8))


filenames = os.listdir(dir11)
for filename in tqdm(filenames):
        im1 = cv2.imread(os.path.join(dir11, filename), cv2.IMREAD_COLOR)
        im1 = cv2.resize(im1, (560, 560))
        im2 = cv2.imread(os.path.join(dir13, filename), cv2.IMREAD_COLOR)
        im2 = cv2.resize(im2, (560, 560))
        im3 = cv2.imread(os.path.join(dir17, filename), cv2.IMREAD_COLOR)
        im3 = cv2.resize(im3, (560, 560))

        vis = np.concatenate((im1, im2), axis=1)
        vis = np.concatenate((vis, im3), axis=1)

        plt.imshow(cv2.cvtColor(vis, cv2.COLOR_BGR2RGB), aspect='auto')
        plt.axis('off')
        plt.savefig(os.path.join(out_dir, filename), bbox_inches='tight', dpi=400)
        plt.clf()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-397594c8fa0e> in <module>()
#       6
#       7
# ----> 8 filenames = os.listdir(dir11)
#       9 for filename in tqdm(filenames):
#      10     im1 = cv2.imread(os.path.join(dir11, filename), cv2.IMREAD_COLOR)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '11_13'
